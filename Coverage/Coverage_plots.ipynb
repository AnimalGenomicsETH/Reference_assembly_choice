# %%
setwd("/cluster/work/pausch/temp_scratch/audald/variant_analyses/coverage")
UCD_summary_coverage = read.csv(file = "UCD/summary_coverage.txt", sep = "\t", header = TRUE)
Angus_summary_coverage = read.csv(file = "Angus/summary_coverage.txt", sep = "\t", header = TRUE)
head(UCD_summary_coverage)
head(Angus_summary_coverage)
# Out:
#   bam_id                  ITB_id              autosome x     y    PAR   MT
# 1 BSWCHEM120102541330.bam BSWCHEM120102541330  7.87     3.81 5.83  7.91   38.11
# 2 BSWCHEM110203063244.bam BSWCHEM110203063244  9.62     5.09 6.36  8.92    3.86
# 3 BSWCHEM120105187122.bam BSWCHEM120105187122 10.80     5.25 7.88 10.47    4.60
# 4 BSWCHEF120071978076.bam BSWCHEF120071978076 11.80    11.67 0.10 11.67 1738.15
# 5 BSWCHEM120127953255.bam BSWCHEM120127953255  7.61     3.72 5.51  7.44   12.60
# 6 BSWCHEM120110162602.bam BSWCHEM120110162602  7.88     3.78 5.57  7.82    8.90
#   bam_id                  ITB_id              autosome x     y     PAR  MT
# 1 BSWCHEM120102541330.bam BSWCHEM120102541330  7.86     3.59 16.97 4.21 16.97
# 2 BSWCHEM110203063244.bam BSWCHEM110203063244  9.61     4.75 19.52 4.62 19.52
# 3 BSWCHEM120105187122.bam BSWCHEM120105187122 10.79     4.94 22.50 5.76 22.50
# 4 BSWCHEF120071978076.bam BSWCHEF120071978076 11.80    10.98  5.59 6.27  5.59
# ...

# %% [markdown]
# These are the initial rows of the files generated as part of the coverage pipeline. Each BAM file coverage is split into autosomes (what we are interested in) and sexual + mitochondrial chromosomes.
#
# Focussing on the coverage of autosomes, these are the main stats:

# %%
summary(UCD_summary_coverage$autosome)
summary(Angus_summary_coverage$autosome)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    4.20    8.33    9.78   12.17   13.17   63.30
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   4.200   8.325   9.780  12.163  13.160  63.380

# %% [markdown]
# The numbers are very similar in both cases, as we have already seen in the [Cut-off notebook](Cut_off_coverage.ipynb).
#
# Some interesting plots help us confirming that filtering above 9x is a sensible decision:

# %%
hist(UCD_summary_coverage$autosome, xlab = "Coverage", ylab = "samples", main = "Coverage of 243 samples - UCD alignment", xlim = c(0,70), col = "lightblue", border = "pink", breaks = 64)
# Out:
# Plot with title “Coverage of 243 samples - UCD alignment”

# %%
hist(Angus_summary_coverage$autosome, xlab = "Coverage", ylab = "samples", main = "Coverage of 243 samples - Angus alignment", xlim = c(0,70), col = "lightblue", border = "pink", breaks = 64)
# Out:
# Plot with title “Coverage of 243 samples - Angus alignment”
