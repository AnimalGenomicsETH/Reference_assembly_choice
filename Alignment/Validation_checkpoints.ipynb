# %% [markdown]
# # Validation and check points
#
# As summarised in the ["Processing pipeline notebook"](Processing_pipeline.ipynb), a series of steps are needed in order to align the raw data for the two assemblies. Given the multiplicity of steps, the number of potential errors also increase. We definitely need a system in place to check whether all the files are being properly generated. The strategy will be many-folded:
#
# * Make sure that all pipeline steps have been completed
# * Check that all samples have been successfully processed
# * Find out what of the samples have already had applied a QC (by FASTP)
# * Confirm that the number of reads is kept from the raw data to the aligned and sorted BAM files
# * Reduce as much as possible the storage footprint
# * Alternative methods for validating the results
#
# #### Snakemake as tool for tracking and checking results
#
# Snakemake is a very complete workflow manager. It does not only concatenates the different steps, automatise great amount of input files and optimise the resources used for every step, but it also generates specific logs for each and every job. Therefore, providing that logs are duly generated, these are very helpful to track errors in concrete steps. The logs are generated in a specific folder (/cluster/work/pausch/temp_scratch/audald/best_assembly/log_folder), where each rule/step will have a separate folder and each job (one job per sample or on job per read-group, depending on the rule) will have a unique log.
# The name of the logs and the directories are set in advance at the [cluster config file](Snakemake/cluster.json).
#
# Snakemake is also very interesting as you can define whether intermediate files (e.g. QC'ed FASTQ files or unsorted BAM) should be deleted as soon as the following file (e.g. split read-group-specific FASTQ files or de-duplicated and sorted BAM file) is created. This is defined in the very [Snakefile](Snakemake/Snakefile.py).
#
# ### Have all rules been successfully completed for all samples?
#
# This is the first question to answer when the workflow has been completed. Hopefully all the steps will be successfully finished. If this is not the case, no problem, we can run the following lines of code so we really know where the problems arise and what are the concrete errors:

# %%
# %%bash
#
# mydir=success_logs
# root_folder="/cluster/work/pausch/temp_scratch/audald/best_assembly/log_folder"
# folders="fastp split_fastq alignment sambamba_sort sambamba_merge sambamba_flagstat_1 mark_duplicates build_index sambamba_flagstat_2"
# for folder in $folders
# do
#     cd $root_folder/$folder
#     #mkdir $mydir ##Uncomment this line if this is the first time and the success_logs folder does not exist
#     mv $mydir/*.log . ##Uncomment this line if the code is run for new samples. All files in success_logs will be moved back to the right folder
#     echo '------- STEP ' $folder '-------'
#     echo 'Number of samples processed:'
#     ls *.log | wc -l
#     for file in *log
#     do
#         if grep -q 'Successfully completed.' $file
#         then
#             mv $file $mydir
#         else
#             echo $file contains errors
#         fi
#     done
#     echo 'Processed successfully:'
#     ls $mydir/*.log | wc -l
#     echo 'Should the previous numbers be different, samples processed with errors can be found in:' $root_folder/$folder
#     echo ''
# done
# Out:
# ------- STEP  fastp -------
# Number of samples processed:
# 369
# Processed successfully:
# 369
# Should the previous numbers be different, samples processed with errors can be found in: /cluster/work/pausch/temp_scratch/audald/best_assembly/log_folder/fastp
#
# ------- STEP  split_fastq -------
# Number of samples processed:
# 369
# Processed successfully:
# 369
# Should the previous numbers be different, samples processed with errors can be found in: /cluster/work/pausch/temp_scratch/audald/best_assembly/log_folder/split_fastq
#
# ------- STEP  alignment -------
# Number of samples processed:
# 2702
# Processed successfully:
# 2702
# Should the previous numbers be different, samples processed with errors can be found in: /cluster/work/pausch/temp_scratch/audald/best_assembly/log_folder/alignment
#
# ------- STEP  sambamba_sort -------
# Number of samples processed:
# 2702
# Processed successfully:
# 2702
# Should the previous numbers be different, samples processed with errors can be found in: /cluster/work/pausch/temp_scratch/audald/best_assembly/log_folder/sambamba_sort
#
# ------- STEP  sambamba_merge -------
# Number of samples processed:
# 738
# Processed successfully:
# 738
# Should the previous numbers be different, samples processed with errors can be found in: /cluster/work/pausch/temp_scratch/audald/best_assembly/log_folder/sambamba_merge
#
# ------- STEP  sambamba_flagstat_1 -------
# Number of samples processed:
# 738
# Processed successfully:
# 738
# Should the previous numbers be different, samples processed with errors can be found in: /cluster/work/pausch/temp_scratch/audald/best_assembly/log_folder/sambamba_flagstat_1
#
# ------- STEP  mark_duplicates -------
# Number of samples processed:
# 738
# Processed successfully:
# 738
# Should the previous numbers be different, samples processed with errors can be found in: /cluster/work/pausch/temp_scratch/audald/best_assembly/log_folder/mark_duplicates
#
# ------- STEP  build_index -------
# Number of samples processed:
# 738
# Processed successfully:
# 738
# Should the previous numbers be different, samples processed with errors can be found in: /cluster/work/pausch/temp_scratch/audald/best_assembly/log_folder/build_index
#
# ------- STEP  sambamba_flagstat_2 -------
# Number of samples processed:
# 738
# Processed successfully:
# 738
# Should the previous numbers be different, samples processed with errors can be found in: /cluster/work/pausch/temp_scratch/audald/best_assembly/log_folder/sambamba_flagstat_2

# %% [markdown]
# The output should be self explanatory but for the sake of clarification:
# * The logs for each rule are parsed (as many logs as sample/read_group per rule)
# * The logs contain 'Successfully completed.' when the job finished properly
# * These successful logs are moved to a new folder "success_logs"
# * The remaining logs (if any) are counted and deemed as troublesome - specific names are provided
# * The successful logs (in the success folder) are counted
# * The number of the total of logs and the successful logs is provided, so discrepancies can be spotted. Should these discrepancies exist, the folder path is provided so the troublesome logs can be checked.
#
# Ideally, the number of "Processed successfully" samples from the build_index & sambamba_flagstat_2 rules should be n times the number of samples from fastp (where n is the number of alignments - 2 in this project). If this is the case, all fine, good news. If this is not the case, we can check retrospectively the previous steps to see where the error happened. Once checked the cause and fixed, the error logs should be deleted and Snakemake be run again - it will automatically resume the process where it stopped.
#
# Some of the errors found during the validations where in rules "alignment", "sambamba_sort" and "mark_duplicates":
#
# * Alignment: 6 samples (only some of the read-groups, specially when aligning to Angus) retrieved the following error: "job killed after reaching LSF memory usage limit.". This is fixed by increasing the number of resources: from 12 cores and 3000 of memory to 12 cores and 4500 of memory. This is nevertheless not changed in [Cluster config file](Snakemake/cluster.json) as I prefer to fix the 6 samples individually rather than giving too many resources to the other hundreds of samples. The cluster is always giving priority to less memory-consuming jobs.
# * Sambamba-sort fails for several samples with the following error message: "sambamba-sort: Unable to write to stream". According to this [webpage](https://github.com/biod/sambamba/issues/218) the error is the number of temporary files created. The more samples processing altogether the more chances to see these problems. Just by running the pipeline again, this problem vanished.
# * Picard tools: There is the following error message for one sample when running Picard tools: "Suppressed: java.io.IOException: No space left on device". Having seen the experience of Sambamba-sort failure, I just try to run again the pipeline and it just works.
#
# We might be interested in getting the sample ID out of the log files, so we easily spot the affected sample (e.g. we want to run the whole pipeline again for the troublesome sample). The following commands are used for extracting the sample ID from the validation steps described above. It is important to notice that *awk* is being used differently depending on the name of the log; it can be adapted to other rules:

# %%
# %%bash
# cd /cluster/work/pausch/temp_scratch/audald/best_assembly/log_folder
# echo 'Failing samples:'
# grep 'exited' alignment/*log | awk -F '_' '{print $3}' | sort -u
# echo 'Failing samples:'
# grep 'exited' sambamba_sort/*log | awk -F '_' '{print $4}' | sort -u
# echo 'Failing samples:'
# grep 'exited' mark_duplicates/*log | ls *log | awk -F '_' '{print $4}' | awk -F '.' '{print $1}' | sort -u

# %% [markdown]
# ### Is the number of samples expected?
#
# At this point we need to compare the number of processed samples and the number of expected samples.
#
# According to the previous script output, 369 samples have been processed (369 samples at the beginning and 369 x n at the end of the pipeline, where n is the number of reference genomes).
#
# According to the [ID criteria selection notebook](../Data/IDs/OBV_BSW_raw_IDs_R.ipynb), 371 animals meet the selection criteria from the metada file (i.e. are OBV or BSW breeds).
#
# When looking at the [Selected samples notebook](../Data/IDs/OBV_BSW_raw_IDs_python.ipynb), 1 of the animals appears not to have raw data: **RM763**. Therefore, 370 samples remain.
#
# However, one out of the 370 being processed is not accepted by the pipeline. This is sample **SRR6067094**, whose raw data appear not to have read groups well defined. Consequently, FASTQ files cannot be split and the process is stopped. It is possible that the trouble is due by the fact that raw data were downloaded from NCBI. Hubert acknowledges that this is possible and raises that he had to use dummy readgroups to process such files in the past.
#
# In a nutshell: from 371 samples meeting the metadata criteria, 2 have been excluded (RM763 and SRR6067094) and hence 369 samples is the final and justified number.
#
# ### Are there any samples that were already applied a QC - FASTP?
#
# Raw data are taken as FASTQ files as input for the processing workflow. Some of the samples are generated by us, used for other projects, downloaded from public repositories, etc. It is therefore difficult to trace back the origin and know the quality of such files. This is partially why we apply a QC (by using FASTP) to all the samples. At this point, though, we would like to know what of the samples had been already applied a QC before and what of the samples are still unfiltered by the time this pipeline is run.
#
# FASTP reports [see here](Fastp.ipynb) are very useful to know the number of reads/bases filtered out due to low quality during the FASTP QC.
#
# The following code helps finding out what of the samples have been already applied a QC:

# %%
# %%bash
#
# module load jq/1.5
#
# path="/cluster/work/pausch/temp_scratch/audald/best_assembly"
# cd $path
# mkdir QC
# touch QC/first_QC.txt
# touch QC/second_QC.txt
# for sample in `ls fastp | xargs -n 1 basename | awk -F " " '{print $1}'`
# do
#     cat fastp/$sample/${sample}_fastp.json | jq '.summary.before_filtering.total_reads' > QC/${sample}_bf_reads.txt
#     cat fastp/$sample/${sample}_fastp.json | jq '.summary.after_filtering.total_reads' > QC/${sample}_af_reads.txt
#     bf_reads=$(cat QC/${sample}_bf_reads.txt)
#     af_reads=$(cat QC/${sample}_af_reads.txt)
#     if [ $bf_reads == $af_reads ]; then
#         echo $sample >> QC/second_QC.txt
#     else
#         echo $sample >> QC/first_QC.txt
#     fi
# done
# echo --------------------------------------------------------------------------------------------------------
# echo Samples with previous QC:
# cat QC/second_QC.txt | wc -l
# cat QC/second_QC.txt
# echo --------------------------------------------------------------------------------------------------------
# The above code is looping over all the samples a comparison between the reads of raw data before the filtering and after the filter.
# When the number of reads before and after the filtering is the same (*i.e.* filtering does not affect) we assume that a previous QC had been already applied.
#
# ### Is the number of reads kept across the pipeline?
#
# Once the Quality Control (QC - FASTP) has been applied to the raw data, there are no other steps where reads are filtered out from the files. Therefore, we would expect as many reads in the QC'ed FASTQ files as in the de-duplicated and sorted BAM files. The following lines of code are used for this check:

# %%
# %%bash
# module load jq/1.5
# samples="BSWDEUF000948260022 BSWCHEM120074028822"
# path="/cluster/work/pausch/temp_scratch/audald/best_assembly"
# cd $path
# mkdir QC
# touch QC/matching_reads.txt
# touch QC/discrepant_reads.txt
# for sample in $samples
# do
#     echo '---------- Sample' $sample '----------'
#     echo 'Reads after FASTP filtering:'
#     cat fastp/$sample/${sample}_fastp.json | jq '.summary.after_filtering.total_reads' > QC/${sample}_fastp.txt
#     QC_fastp=$(cat QC/${sample}_fastp.txt)
#     echo $QC_fastp
#     echo 'Reads after FASTQ splitting:'
#     cat split_fastq/$sample/*report.json | jq '.metadata.record_count' | paste -sd+ | bc > QC/${sample}_split.txt
#     QC_split=$(cat QC/${sample}_split.txt)
#     echo $QC_split
#     echo 'Reads after alignment and deduplication step - UCD alignment:'
#     cat dedup_alignment/UCD/$sample/$sample.stats | grep 'QC-passed reads' | awk '{print $1}' > QC/${sample}_bam_pass_UCD.txt
#     QC_pass_UCD=$(cat QC/${sample}_bam_pass_UCD.txt)
#     cat dedup_alignment/UCD/$sample/$sample.stats | grep 'secondary' | awk '{print $1}' > QC/${sample}_bam_sec_UCD.txt
#     QC_sec_UCD=$(cat QC/${sample}_bam_sec_UCD.txt)
#     reads_UCD=$((QC_pass_UCD-QC_sec_UCD))
#     echo $reads_UCD > QC/${sample}_bam_reads_UCD.txt
#     echo $reads_UCD
#     echo 'Reads after alignment and deduplication step - Angus alignment:'
#     cat dedup_alignment/Angus/$sample/$sample.stats | grep 'QC-passed reads' | awk '{print $1}' > QC/${sample}_bam_pass_Angus.txt
#     QC_pass_Angus=$(cat QC/${sample}_bam_pass_Angus.txt)
#     cat dedup_alignment/Angus/$sample/$sample.stats | grep 'secondary' | awk '{print $1}' > QC/${sample}_bam_sec_Angus.txt
#     QC_sec_Angus=$(cat QC/${sample}_bam_sec_Angus.txt)
#     reads_Angus=$((QC_pass_Angus-QC_sec_Angus))
#     echo $reads_Angus > QC/${sample}_bam_reads_Angus.txt
#     echo $reads_Angus
#     md5_reads_fastp=$(md5sum QC/${sample}_fastp.txt | awk -F ' ' '{print $1}')
#     md5_reads_split=$(md5sum QC/${sample}_split.txt | awk -F ' ' '{print $1}')
#     md5_reads_UCD=$(md5sum QC/${sample}_bam_reads_UCD.txt | awk -F ' ' '{print $1}')
#     md5_reads_Angus=$(md5sum QC/${sample}_bam_reads_Angus.txt | awk -F ' ' '{print $1}')
#     if [ $md5_reads_fastp == $md5_reads_split ] && [ $md5_reads_split == $md5_reads_UCD ] && [ $md5_reads_UCD == $md5_reads_Angus ]; then
#         echo $sample >> QC/matching_reads.txt
#     else
#         echo $sample >> QC/discrepant_reads.txt
#     fi
#     rm QC/${sample}*
# done
# echo --------------------------------------------------------------------------------------------------------
# echo Samples with expected reads:
# cat QC/matching_reads.txt | wc -l
# cat QC/matching_reads.txt
# echo --------------------------------------------------------------------------------------------------------
# echo Samples with discrepant reads:
# cat QC/discrepant_reads.txt | wc -l
# cat QC/discrepant_reads.txt
# rm -r QC
# Out:
# ---------- Sample BSWDEUF000948260022 ----------
# Reads after FASTP filtering:
# 218362236
# Reads after FASTQ splitting:
# 218362236
# Reads after alignment and deduplication step - UCD alignment:
# 218362236
# Reads after alignment and deduplication step - Angus alignment:
# 218362236
# ---------- Sample BSWCHEM120074028822 ----------
# Reads after FASTP filtering:
# 264501772
# Reads after FASTQ splitting:
# 264501772
# Reads after alignment and deduplication step - UCD alignment:
# 264501772
# Reads after alignment and deduplication step - Angus alignment:
# 264501772
# --------------------------------------------------------------------------------------------------------
# Samples with expected reads:
# 2
# BSWDEUF000948260022
# BSWCHEM120074028822
# --------------------------------------------------------------------------------------------------------
# Samples with discrepant reads:
# 0

# %% [markdown]
# The above script is a test for two samples (BSWDEUF000948260022 and BSWCHEM120074028822) to check the different read groups during the pipeline.
#
# First of all, a QC folder is created for the generation of temporary files including the number of reads for each sample in the following steps:
# * After FASTP, by parsing and extracting the number of reads from the JSON of the QC'ed fastq files
# * After splitting the files, by parsing and summing up the number of reads from the JSON of the different read-group-specific fastq files
# * At the end of the pipeline, after the deduplication step. QC-passed reads and secondary reads are extracted from the summary files generated by Picard tools, for both assemblies. The total number of reads is the substraction of the secondary reads minus the QC-passed reads.
#
# The reads of the different steps are listed and displayed for visual checking. However, in order to programmatically compare and pinpoint the discrepant samples, the following strategy is proposed:
# * The four intermediate files (reads after FASTP, reads after splitting, reads after Picard tools for UCD and reads after Picard tools for Angus) are compared by checking the md5 sums
# * Should the md5 values for the four files match, the sample name is included in a text file with successful samples.
# * Should the md5 values not match, the sample name is included in a text file with discrepant samples
#
# Having seen the good performance of the script, the check is run for all the samples - loop for all samples existing at the beginning of the pipeline - note that this step can be run only when all rules have been successfully completed for all samples (see script above):

# %%
# %%bash
#
# module load jq/1.5
# path="/cluster/work/pausch/temp_scratch/audald/best_assembly"
# cd $path
# mkdir QC
# touch QC/matching_reads.txt
# touch QC/discrepant_reads.txt
# for sample in `ls fastp/ | xargs -n 1 basename | awk -F " " '{print $1}'`
# do
#     cat fastp/$sample/${sample}_fastp.json | jq '.summary.after_filtering.total_reads' > QC/${sample}_fastp.txt
#     QC_fastp=$(cat QC/${sample}_fastp.txt)
#     cat split_fastq/$sample/*report.json | jq '.metadata.record_count' | paste -sd+ | bc > QC/${sample}_split.txt
#     QC_split=$(cat QC/${sample}_split.txt)
#     cat dedup_alignment/UCD/$sample/$sample.stats | grep 'QC-passed reads' | awk '{print $1}' > QC/${sample}_bam_pass_UCD.txt
#     QC_pass_UCD=$(cat QC/${sample}_bam_pass_UCD.txt)
#     cat dedup_alignment/UCD/$sample/$sample.stats | grep 'secondary' | awk '{print $1}' > QC/${sample}_bam_sec_UCD.txt
#     QC_sec_UCD=$(cat QC/${sample}_bam_sec_UCD.txt)
#     reads_UCD=$((QC_pass_UCD-QC_sec_UCD))
#     echo $reads_UCD > QC/${sample}_bam_reads_UCD.txt
#     cat dedup_alignment/Angus/$sample/$sample.stats | grep 'QC-passed reads' | awk '{print $1}' > QC/${sample}_bam_pass_Angus.txt
#     QC_pass_Angus=$(cat QC/${sample}_bam_pass_Angus.txt)
#     cat dedup_alignment/Angus/$sample/$sample.stats | grep 'secondary' | awk '{print $1}' > QC/${sample}_bam_sec_Angus.txt
#     QC_sec_Angus=$(cat QC/${sample}_bam_sec_Angus.txt)
#     reads_Angus=$((QC_pass_Angus-QC_sec_Angus))
#     echo $reads_Angus > QC/${sample}_bam_reads_Angus.txt
#     md5_reads_fastp=$(md5sum QC/${sample}_fastp.txt | awk -F ' ' '{print $1}')
#     md5_reads_split=$(md5sum QC/${sample}_split.txt | awk -F ' ' '{print $1}')
#     md5_reads_UCD=$(md5sum QC/${sample}_bam_reads_UCD.txt | awk -F ' ' '{print $1}')
#     md5_reads_Angus=$(md5sum QC/${sample}_bam_reads_Angus.txt | awk -F ' ' '{print $1}')
#     if [ $md5_reads_fastp == $md5_reads_split ] && [ $md5_reads_split == $md5_reads_UCD ] && [ $md5_reads_UCD == $md5_reads_Angus ]; then
#         echo $sample >> QC/matching_reads.txt
#     else
#         echo $sample >> QC/discrepant_reads.txt
#     fi
#     rm QC/${sample}*
# done
# echo --------------------------------------------------------------------------------------------------------
# echo Total number of samples:
# ls fastp/ | wc -l
# echo --------------------------------------------------------------------------------------------------------
# echo Samples with expected reads:
# cat QC/matching_reads.txt | wc -l
# echo --------------------------------------------------------------------------------------------------------
# echo Samples with discrepant reads:
# cat QC/discrepant_reads.txt | wc -l
# cat QC/discrepant_reads.txt
# rm -r QC
# Out:
# --------------------------------------------------------------------------------------------------------
# Total number of samples:
# 369
# --------------------------------------------------------------------------------------------------------
# Samples with expected reads:
# 369
# --------------------------------------------------------------------------------------------------------
# Samples with discrepant reads:
# 0

# %% [markdown]
# ### Is my storage footprint too high?
#
# One of the main advantages of deleting the intermediate files as the following ones are created (part of the Snakemake process) is that not all files are stored, so the footprint is not that high. However, some of the intermediate files (namely splitting fastq files) are kept after running the pipeline.
#
# If all the pipeline steps are fine and all the samples have the proper number of reads, my advice would be to reduce the footprint by removing the read-group-specific fastq files providing that the above sections were successful.

# %%
# %%bash
#
# cd /cluster/work/pausch/temp_scratch/audald/best_assembly/split_fastq
# rm */*fq.gz

# %% [markdown]
# Let us check the size of the resulting files:

# %%
# %%bash
#
# cd /cluster/work/pausch/temp_scratch/
# du -hs audald/
# du -hs audald/best_assembly
# du -hs audald/best_assembly/dedup_alignment
# Out:
# 15T	audald/
# 14T	audald/best_assembly
# 14T	audald/best_assembly/dedup_alignment

# %% [markdown]
# ### Alternative, advanced and secondary checks
#
#     echo 'File created for' $sample #Completing the loop
# done

# %% [markdown]
# Once this is completed we end up with one text file per sample from where we can retrieve the read groups. Ideally, there should be as many read-group-specific fastq files as read groups. Actually, we are expecting twice as many fastq files and BAM files as read groups:
# * R1 and R2 fastq files per read group
# * UCD and ANGUS BAM files per read group
#
# If this is correct, we can also take a look at the size; whether it seems to make sense. We would be expecting a similiar amount of Gb before splitting the fastq and after the split (summing up the splitted fastq). We would also be expecting a bit more than 2x for read-group-specific BAM files).
#
# The second script (python) includes loops that permit the easy visualisation of number of files, size of the files and lists for files correctly processed and wrongly processed:

# %%
import os
import fnmatch

samples = "BSWAUTM000077152128",  "BSWAUTM000217825118",  "BSWCHEF120043744524",  "BSWCHEF120050280619",  "BSWCHEF120066378591",  "BSWCHEF120069106030",  "BSWCHEF120071978076",  "BSWCHEF120075378834",  "BSWCHEF120082542037",  "BSWCHEF120107227826",  "BSWCHEF120108040714",  "BSWCHEF120110871894",  "BSWCHEF120114550399",  "BSWCHEF120114550405",  "BSWCHEF120124686545",  "BSWCHEF120127240430",  "BSWCHEF120130256848",  "BSWCHEF120136261792",  "BSWCHEF120144682558",  "BSWCHEM110008038300",  "BSWCHEM110011106478",  "BSWCHEM110023148411",  "BSWCHEM110043090653",  "BSWCHEM110057253457",  "BSWCHEM110060137584",  "BSWCHEM110069121003",  "BSWCHEM110097174286",  "BSWCHEM110097189518",  "BSWCHEM110098045882",  "BSWCHEM110098071188",  "BSWCHEM110106053793",  "BSWCHEM110111072321",  "BSWCHEM110121201483",  "BSWCHEM110131060582",  "BSWCHEM110153046663",  "BSWCHEM110173016820",  "BSWCHEM110177093315",  "BSWCHEM110200059950",  "BSWCHEM110203063244",  "BSWCHEM110211065827",  "BSWCHEM110218087570",  "BSWCHEM110246097145",  "BSWCHEM110262082439",  "BSWCHEM110265057175",  "BSWCHEM110269048407",  "BSWCHEM110276043280",  "BSWCHEM110294048847",  "BSWCHEM110349149437",  "BSWCHEM110374046077",  "BSWCHEM110471084194",  "BSWCHEM110480021128",  "BSWCHEM110482036847",  "BSWCHEM110501069856",  "BSWCHEM110556008244",  "BSWCHEM110706016501",  "BSWCHEM110711018798",  "BSWCHEM110716018779",  "BSWCHEM110716027719",  "BSWCHEM110785019936",  "BSWCHEM110967005528",  "BSWCHEM110967032609",  "BSWCHEM111030024286",  "BSWCHEM111452065584",  "BSWCHEM111453045080",  "BSWCHEM111512030200",  "BSWCHEM120000414675",  "BSWCHEM120004573248",  "BSWCHEM120020086135",  "BSWCHEM120026503698",  "BSWCHEM120031901830",  "BSWCHEM120032196501",  "BSWCHEM120032300663",  "BSWCHEM120033040506",  "BSWCHEM120038685214",  "BSWCHEM120040689392",  "BSWCHEM120047653969",  "BSWCHEM120052037815",  "BSWCHEM120052893046",  "BSWCHEM120053474381",  "BSWCHEM120053485530",  "BSWCHEM120054755137",  "BSWCHEM120
matching_samples= list()
non_matching_samples= list()
for sample in samples:
    print(sample)
    read_group_file = "/cluster/work/pausch/temp_scratch/audald/read_groups/"+sample+"_readgroups.txt"
    read_group_file = open(read_group_file, 'r')
    read_groups = read_group_file.readlines()
    for read_group in read_groups:
        read_group = read_group.strip()
        #print(read_group)
    print("Number of read groups: ")
    print(len(read_groups))
    all_bam_files=os.listdir("/cluster/work/pausch/temp_scratch/audald/sorted_alignment/"+sample)
    bam_files = list()
    size_bam_files = list()
    for file in all_bam_files:
        if fnmatch.fnmatch(file, '*.bam'):
            bam_files.append(file)
            bam_file_size = os.path.getsize("/cluster/work/pausch/temp_scratch/audald/alignment/"+sample+"/"+file)
            bam_file_size = round(bam_file_size/1024/1024/1024,1)
            size_bam_files.append(bam_file_size)
    #print(sorted(bam_files))
    print("Number of bam files: ")
    print(len(bam_files))
    #print(size_bam_files)
    print("Total size of bam files in Gb:")
    print(round(sum(size_bam_files),1))
    print("Do the number of files match?")
    if (len(read_groups)*2) == len(bam_files):
        print("All good!")
        matching_samples.append(sample)
    else:
        print("Nope, it does not match!")
        non_matching_samples.append(sample)
    print("")
print("--------------------------")
print("Matching samples: ")
print(len(matching_samples))
print(matching_samples)
print("Non matching samples: ") 
print(len(non_matching_samples))
print(non_matching_samples)
# Out:
# BSWAUTM000077152128
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 84.6
# Do the number of files match?
# All good!
#
# BSWAUTM000217825118
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 122.1
# Do the number of files match?
# All good!
#
# BSWCHEF120043744524
# Number of read groups:
# 13
# Number of bam files:
# 26
# Total size of bam files in Gb:
# 79.7
# Do the number of files match?
# All good!
#
# BSWCHEF120050280619
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 77.0
# Do the number of files match?
# All good!
#
# BSWCHEF120066378591
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 77.9
# Do the number of files match?
# All good!
#
# BSWCHEF120069106030
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 78.5
# Do the number of files match?
# All good!
#
# BSWCHEF120071978076
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 62.0
# Do the number of files match?
# All good!
#
# BSWCHEF120075378834
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 103.2
# Do the number of files match?
# All good!
#
# BSWCHEF120082542037
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 65.9
# Do the number of files match?
# All good!
#
# BSWCHEF120107227826
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 70.8
# Do the number of files match?
# All good!
#
# BSWCHEF120108040714
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 62.3
# Do the number of files match?
# All good!
#
# BSWCHEF120110871894
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 90.6
# Do the number of files match?
# All good!
#
# BSWCHEF120114550399
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 68.7
# Do the number of files match?
# All good!
#
# BSWCHEF120114550405
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 82.4
# Do the number of files match?
# All good!
#
# BSWCHEF120124686545
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 118.5
# Do the number of files match?
# All good!
#
# BSWCHEF120127240430
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 105.2
# Do the number of files match?
# All good!
#
# BSWCHEF120130256848
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 151.6
# Do the number of files match?
# All good!
#
# BSWCHEF120136261792
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 87.7
# Do the number of files match?
# All good!
#
# BSWCHEF120144682558
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 63.7
# Do the number of files match?
# All good!
#
# BSWCHEM110008038300
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 58.7
# Do the number of files match?
# All good!
#
# BSWCHEM110011106478
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 43.2
# Do the number of files match?
# All good!
#
# BSWCHEM110023148411
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 71.2
# Do the number of files match?
# All good!
#
# BSWCHEM110043090653
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 74.1
# Do the number of files match?
# All good!
#
# BSWCHEM110057253457
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 67.1
# Do the number of files match?
# All good!
#
# BSWCHEM110060137584
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 45.4
# Do the number of files match?
# All good!
#
# BSWCHEM110069121003
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 36.6
# Do the number of files match?
# All good!
#
# BSWCHEM110097174286
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 32.3
# Do the number of files match?
# All good!
#
# BSWCHEM110097189518
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 59.5
# Do the number of files match?
# All good!
#
# BSWCHEM110098045882
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 35.9
# Do the number of files match?
# All good!
#
# BSWCHEM110098071188
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 71.5
# Do the number of files match?
# All good!
#
# BSWCHEM110106053793
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 60.5
# Do the number of files match?
# All good!
#
# BSWCHEM110111072321
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 42.3
# Do the number of files match?
# All good!
#
# BSWCHEM110121201483
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 70.0
# Do the number of files match?
# All good!
#
# BSWCHEM110131060582
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 36.8
# Do the number of files match?
# All good!
#
# BSWCHEM110153046663
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 65.2
# Do the number of files match?
# All good!
#
# BSWCHEM110173016820
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 58.0
# Do the number of files match?
# All good!
#
# BSWCHEM110177093315
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 36.8
# Do the number of files match?
# All good!
#
# BSWCHEM110200059950
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 54.5
# Do the number of files match?
# All good!
#
# BSWCHEM110203063244
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 48.1
# Do the number of files match?
# All good!
#
# BSWCHEM110211065827
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 49.3
# Do the number of files match?
# All good!
#
# BSWCHEM110218087570
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 36.0
# Do the number of files match?
# All good!
#
# BSWCHEM110246097145
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 50.0
# Do the number of files match?
# All good!
#
# BSWCHEM110262082439
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 36.3
# Do the number of files match?
# All good!
#
# BSWCHEM110265057175
# Number of read groups:
# 6
# Number of bam files:
# 12
# Total size of bam files in Gb:
# 48.0
# Do the number of files match?
# All good!
#
# BSWCHEM110269048407
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 59.1
# Do the number of files match?
# All good!
#
# BSWCHEM110276043280
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 49.1
# Do the number of files match?
# All good!
#
# BSWCHEM110294048847
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 37.8
# Do the number of files match?
# All good!
#
# BSWCHEM110349149437
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 39.0
# Do the number of files match?
# All good!
#
# BSWCHEM110374046077
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 63.3
# Do the number of files match?
# All good!
#
# BSWCHEM110471084194
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 54.7
# Do the number of files match?
# All good!
#
# BSWCHEM110480021128
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 61.1
# Do the number of files match?
# All good!
#
# BSWCHEM110482036847
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 60.9
# Do the number of files match?
# All good!
#
# BSWCHEM110501069856
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 69.9
# Do the number of files match?
# All good!
#
# BSWCHEM110556008244
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 57.7
# Do the number of files match?
# All good!
#
# BSWCHEM110706016501
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 67.9
# Do the number of files match?
# All good!
#
# BSWCHEM110711018798
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 56.0
# Do the number of files match?
# All good!
#
# BSWCHEM110716018779
# Number of read groups:
# 6
# Number of bam files:
# 12
# Total size of bam files in Gb:
# 47.3
# Do the number of files match?
# All good!
#
# BSWCHEM110716027719
# Number of read groups:
# 6
# Number of bam files:
# 12
# Total size of bam files in Gb:
# 41.3
# Do the number of files match?
# All good!
#
# BSWCHEM110785019936
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 51.4
# Do the number of files match?
# All good!
#
# BSWCHEM110967005528
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 31.7
# Do the number of files match?
# All good!
#
# BSWCHEM110967032609
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 40.5
# Do the number of files match?
# All good!
#
# BSWCHEM111030024286
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 61.1
# Do the number of files match?
# All good!
#
# BSWCHEM111452065584
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 36.3
# Do the number of files match?
# All good!
#
# BSWCHEM111453045080
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 62.1
# Do the number of files match?
# All good!
#
# BSWCHEM111512030200
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 52.7
# Do the number of files match?
# All good!
#
# BSWCHEM120000414675
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 76.5
# Do the number of files match?
# All good!
#
# BSWCHEM120004573248
# Number of read groups:
# 6
# Number of bam files:
# 12
# Total size of bam files in Gb:
# 45.7
# Do the number of files match?
# All good!
#
# BSWCHEM120020086135
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 40.9
# Do the number of files match?
# All good!
#
# BSWCHEM120026503698
# Number of read groups:
# 6
# Number of bam files:
# 12
# Total size of bam files in Gb:
# 40.8
# Do the number of files match?
# All good!
#
# BSWCHEM120031901830
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 95.7
# Do the number of files match?
# All good!
#
# BSWCHEM120032196501
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 76.4
# Do the number of files match?
# All good!
#
# BSWCHEM120032300663
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 40.0
# Do the number of files match?
# All good!
#
# BSWCHEM120033040506
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 44.1
# Do the number of files match?
# All good!
#
# BSWCHEM120038685214
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 41.7
# Do the number of files match?
# All good!
#
# BSWCHEM120040689392
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 38.1
# Do the number of files match?
# All good!
#
# BSWCHEM120047653969
# Number of read groups:
# 6
# Number of bam files:
# 12
# Total size of bam files in Gb:
# 39.6
# Do the number of files match?
# All good!
#
# BSWCHEM120052037815
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 39.0
# Do the number of files match?
# All good!
#
# BSWCHEM120052893046
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 32.1
# Do the number of files match?
# All good!
#
# BSWCHEM120053474381
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 27.5
# Do the number of files match?
# All good!
#
# BSWCHEM120053485530
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 39.5
# Do the number of files match?
# All good!
#
# BSWCHEM120054755137
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 48.2
# Do the number of files match?
# All good!
#
# BSWCHEM120054800752
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 43.7
# Do the number of files match?
# All good!
#
# BSWCHEM120059624513
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 55.8
# Do the number of files match?
# All good!
#
# BSWCHEM120060730418
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 44.9
# Do the number of files match?
# All good!
#
# BSWCHEM120062337035
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 76.5
# Do the number of files match?
# All good!
#
# BSWCHEM120062497968
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 35.5
# Do the number of files match?
# All good!
#
# BSWCHEM120064046362
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 37.8
# Do the number of files match?
# All good!
#
# BSWCHEM120066618543
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 34.9
# Do the number of files match?
# All good!
#
# BSWCHEM120066947247
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 111.4
# Do the number of files match?
# All good!
#
# BSWCHEM120070555216
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 42.1
# Do the number of files match?
# All good!
#
# BSWCHEM120070757016
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 47.6
# Do the number of files match?
# All good!
#
# BSWCHEM120074415035
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 34.7
# Do the number of files match?
# All good!
#
# BSWCHEM120078454467
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 37.3
# Do the number of files match?
# All good!
#
# BSWCHEM120079379790
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 254.0
# Do the number of files match?
# All good!
#
# BSWCHEM120088525126
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 45.0
# Do the number of files match?
# All good!
#
# BSWCHEM120089597801
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 35.7
# Do the number of files match?
# All good!
#
# BSWCHEM120089597825
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 32.5
# Do the number of files match?
# All good!
#
# BSWCHEM120094785965
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 182.9
# Do the number of files match?
# All good!
#
# BSWCHEM120098716606
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 44.2
# Do the number of files match?
# All good!
#
# BSWCHEM120100176039
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 34.0
# Do the number of files match?
# All good!
#
# BSWCHEM120101096138
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 46.1
# Do the number of files match?
# All good!
#
# BSWCHEM120102474324
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 48.1
# Do the number of files match?
# All good!
#
# BSWCHEM120102474546
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 34.3
# Do the number of files match?
# All good!
#
# BSWCHEM120103533136
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 56.1
# Do the number of files match?
# All good!
#
# BSWCHEM120105020658
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 63.1
# Do the number of files match?
# All good!
#
# BSWCHEM120111313935
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 54.0
# Do the number of files match?
# All good!
#
# BSWCHEM120112699038
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 35.1
# Do the number of files match?
# All good!
#
# BSWCHEM120126513481
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 38.3
# Do the number of files match?
# All good!
#
# BSWCHEM120134766497
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 39.1
# Do the number of files match?
# All good!
#
# BSWCHEM120134769801
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 40.6
# Do the number of files match?
# All good!
#
# BSWDEUM000910075535
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 27.0
# Do the number of files match?
# All good!
#
# BSWDEUM000910195137
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 71.9
# Do the number of files match?
# All good!
#
# BSWDEUM000940438790
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 67.1
# Do the number of files match?
# All good!
#
# BSWDEUM000942296230
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 63.6
# Do the number of files match?
# All good!
#
# BSWDEUM000943355630
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 51.7
# Do the number of files match?
# All good!
#
# BSWDEUM000943861630
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 44.1
# Do the number of files match?
# All good!
#
# BSWDEUM000945510719
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 64.0
# Do the number of files match?
# All good!
#
# BSWDEUM000945581509
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 60.9
# Do the number of files match?
# All good!
#
# BSWUSAM000000184087
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 67.3
# Do the number of files match?
# All good!
#
# BSWUSAM000000184138
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 66.9
# Do the number of files match?
# All good!
#
# BSWUSAM000000187361
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 69.9
# Do the number of files match?
# All good!
#
# BSWUSAM000000189182
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 59.7
# Do the number of files match?
# All good!
#
# BSWUSAM000000189797
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 61.9
# Do the number of files match?
# All good!
#
# NDA032
# Number of read groups:
# 16
# Number of bam files:
# 32
# Total size of bam files in Gb:
# 61.7
# Do the number of files match?
# All good!
#
# RM067
# Number of read groups:
# 6
# Number of bam files:
# 12
# Total size of bam files in Gb:
# 57.6
# Do the number of files match?
# All good!
#
# RM1003
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 52.8
# Do the number of files match?
# All good!
#
# RM1118
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 59.9
# Do the number of files match?
# All good!
#
# RM1179
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 70.1
# Do the number of files match?
# All good!
#
# RM1293
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 89.2
# Do the number of files match?
# All good!
#
# RM1478
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 86.2
# Do the number of files match?
# All good!
#
# RM1512
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 100.1
# Do the number of files match?
# All good!
#
# RM1898
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 104.6
# Do the number of files match?
# All good!
#
# RM1899
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 98.7
# Do the number of files match?
# All good!
#
# RM1900
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 106.3
# Do the number of files match?
# All good!
#
# RM1901
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 109.4
# Do the number of files match?
# All good!
#
# RM1905
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 113.1
# Do the number of files match?
# All good!
#
# RM1906
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 95.8
# Do the number of files match?
# All good!
#
# RM2009
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 124.6
# Do the number of files match?
# All good!
#
# RM720
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 20.2
# Do the number of files match?
# All good!
#
# RM721
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 32.5
# Do the number of files match?
# All good!
#
# RM723
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 48.6
# Do the number of files match?
# All good!
#
# RM730
# Number of read groups:
# 11
# Number of bam files:
# 22
# Total size of bam files in Gb:
# 31.1
# Do the number of files match?
# All good!
#
# RM806
# Number of read groups:
# 9
# Number of bam files:
# 18
# Total size of bam files in Gb:
# 56.8
# Do the number of files match?
# All good!
#
# RM808
# Number of read groups:
# 9
# Number of bam files:
# 18
# Total size of bam files in Gb:
# 58.5
# Do the number of files match?
# All good!
#
# RM854
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 139.2
# Do the number of files match?
# All good!
#
# RM855
# Number of read groups:
# 16
# Number of bam files:
# 32
# Total size of bam files in Gb:
# 60.8
# Do the number of files match?
# All good!
#
# RM884
# Number of read groups:
# 16
# Number of bam files:
# 32
# Total size of bam files in Gb:
# 63.9
# Do the number of files match?
# All good!
#
# RM887
# Number of read groups:
# 10
# Number of bam files:
# 20
# Total size of bam files in Gb:
# 38.9
# Do the number of files match?
# All good!
#
# RM937
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 48.0
# Do the number of files match?
# All good!
#
# RM938
# Number of read groups:
# 16
# Number of bam files:
# 32
# Total size of bam files in Gb:
# 58.7
# Do the number of files match?
# All good!
#
# RM945
# Number of read groups:
# 18
# Number of bam files:
# 36
# Total size of bam files in Gb:
# 64.8
# Do the number of files match?
# All good!
#
# RM947
# Number of read groups:
# 18
# Number of bam files:
# 36
# Total size of bam files in Gb:
# 64.0
# Do the number of files match?
# All good!
#
# RM948
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 54.8
# Do the number of files match?
# All good!
#
# RM951
# Number of read groups:
# 18
# Number of bam files:
# 36
# Total size of bam files in Gb:
# 63.9
# Do the number of files match?
# All good!
#
# RM963
# Number of read groups:
# 18
# Number of bam files:
# 36
# Total size of bam files in Gb:
# 57.6
# Do the number of files match?
# All good!
#
# RM996
# Number of read groups:
# 9
# Number of bam files:
# 18
# Total size of bam files in Gb:
# 59.1
# Do the number of files match?
# All good!
#
# RM997
# Number of read groups:
# 9
# Number of bam files:
# 18
# Total size of bam files in Gb:
# 49.1
# Do the number of files match?
# All good!
#
# RM998
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 44.7
# Do the number of files match?
# All good!
#
# BSWAUTM000336344707
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 43.7
# Do the number of files match?
# All good!
#
# BSWCHEF120023224572
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 125.8
# Do the number of files match?
# All good!
#
# BSWCHEF120071057962
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 199.3
# Do the number of files match?
# All good!
#
# BSWCHEF120080761164
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 96.1
# Do the number of files match?
# All good!
#
# BSWCHEF120104805454
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 93.0
# Do the number of files match?
# All good!
#
# BSWCHEF120108462332
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 81.8
# Do the number of files match?
# All good!
#
# BSWCHEF120118254972
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 90.4
# Do the number of files match?
# All good!
#
# BSWCHEF120118511723
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 108.3
# Do the number of files match?
# All good!
#
# BSWCHEF120121047356
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 127.5
# Do the number of files match?
# All good!
#
# BSWCHEF120127770289
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 173.0
# Do the number of files match?
# All good!
#
# BSWCHEF120145581935
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 76.1
# Do the number of files match?
# All good!
#
# BSWCHEM110009030235
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 42.7
# Do the number of files match?
# All good!
#
# BSWCHEM110023102796
# Number of read groups:
# 6
# Number of bam files:
# 12
# Total size of bam files in Gb:
# 42.4
# Do the number of files match?
# All good!
#
# BSWCHEM110040047292
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 66.9
# Do the number of files match?
# All good!
#
# BSWCHEM110098063770
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 58.7
# Do the number of files match?
# All good!
#
# BSWCHEM110222168241
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 40.0
# Do the number of files match?
# All good!
#
# BSWCHEM110254129111
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 44.6
# Do the number of files match?
# All good!
#
# BSWCHEM110280223340
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 55.9
# Do the number of files match?
# All good!
#
# BSWCHEM110293038924
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 54.6
# Do the number of files match?
# All good!
#
# BSWCHEM110294042272
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 43.5
# Do the number of files match?
# All good!
#
# BSWCHEM110445039823
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 41.7
# Do the number of files match?
# All good!
#
# BSWCHEM110468065700
# Number of read groups:
# 6
# Number of bam files:
# 12
# Total size of bam files in Gb:
# 42.1
# Do the number of files match?
# All good!
#
# BSWCHEM110502100268
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 67.3
# Do the number of files match?
# All good!
#
# BSWCHEM110518030504
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 66.1
# Do the number of files match?
# All good!
#
# BSWCHEM110919005798
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 67.1
# Do the number of files match?
# All good!
#
# BSWCHEM111453050169
# Number of read groups:
# 6
# Number of bam files:
# 12
# Total size of bam files in Gb:
# 49.2
# Do the number of files match?
# All good!
#
# BSWCHEM120027093693
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 83.5
# Do the number of files match?
# All good!
#
# BSWCHEM120033527809
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 57.5
# Do the number of files match?
# All good!
#
# BSWCHEM120033898589
# Number of read groups:
# 6
# Number of bam files:
# 12
# Total size of bam files in Gb:
# 38.5
# Do the number of files match?
# All good!
#
# BSWCHEM120035700514
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 44.7
# Do the number of files match?
# All good!
#
# BSWCHEM120057745616
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 131.6
# Do the number of files match?
# All good!
#
# BSWCHEM120060662634
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 45.0
# Do the number of files match?
# All good!
#
# BSWCHEM120085769301
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 33.1
# Do the number of files match?
# All good!
#
# BSWCHEM120090508056
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 34.4
# Do the number of files match?
# All good!
#
# BSWCHEM120097723193
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 33.7
# Do the number of files match?
# All good!
#
# BSWCHEM120098367211
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 41.6
# Do the number of files match?
# All good!
#
# BSWCHEM120099980013
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 80.8
# Do the number of files match?
# All good!
#
# BSWCHEM120100207702
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 35.5
# Do the number of files match?
# All good!
#
# BSWCHEM120104250872
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 33.2
# Do the number of files match?
# All good!
#
# BSWCHEM120131096320
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 40.1
# Do the number of files match?
# All good!
#
# BSWCHEM120134731440
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 125.1
# Do the number of files match?
# All good!
#
# BSWCHEMRM2549
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 85.4
# Do the number of files match?
# All good!
#
# BSWDEUF09492825451
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 79.2
# Do the number of files match?
# All good!
#
# BSWDEUF09539252639
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 77.6
# Do the number of files match?
# All good!
#
# BSWDEUM000538927305
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 66.8
# Do the number of files match?
# All good!
#
# BSWDEUM000943861279
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 66.2
# Do the number of files match?
# All good!
#
# BSWDEUM000944554741
# Number of read groups:
# 2
# Number of bam files:
# 4
# Total size of bam files in Gb:
# 52.9
# Do the number of files match?
# All good!
#
# BSWDEUM000947736431
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 68.2
# Do the number of files match?
# All good!
#
# BSWDEUM000948243974
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 86.5
# Do the number of files match?
# All good!
#
# BSWDEUM000951442383
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 226.1
# Do the number of files match?
# All good!
#
# BSWDEUM000951444644
# Number of read groups:
# 3
# Number of bam files:
# 6
# Total size of bam files in Gb:
# 199.3
# Do the number of files match?
# All good!
#
# BSWUSAM000000186276
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 63.1
# Do the number of files match?
# All good!
#
# BSWUSAM000000195618
# Number of read groups:
# 1
# Number of bam files:
# 2
# Total size of bam files in Gb:
# 61.3
# Do the number of files match?
# All good!
#
# NDA059
# Number of read groups:
# 16
# Number of bam files:
# 32
# Total size of bam files in Gb:
# 61.8
# Do the number of files match?
# All good!
#
# RM1023
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 70.6
# Do the number of files match?
# All good!
#
# RM1108
# Number of read groups:
# 4
# Number of bam files:
# 8
# Total size of bam files in Gb:
# 110.8
# Do the number of files match?
# All good!
#
# RM1513
# Number of read groups:
# 8
# Number of bam files:
# 16
# Total size of bam files in Gb:
# 105.4
# Do the number of files match?
# All good!
#
# RM1894
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 100.2
# Do the number of files match?
# All good!
#
# RM1896
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 94.1
# Do the number of files match?
# All good!
#
# RM1897
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 99.3
# Do the number of files match?
# All good!
#
# RM1902
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 114.3
# Do the number of files match?
# All good!
#
# RM1903
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 135.2
# Do the number of files match?
# All good!
#
# RM1904
# Number of read groups:
# 5
# Number of bam files:
# 10
# Total size of bam files in Gb:
# 143.2
# Do the number of files match?
# All good!
#
# RM1907
# Number of read groups:
# - BAM files found in the after alignment folder are listed and the number is provided. 2x number of read groups (UCD and Angus is expected)
# - Total size of read-group-specific BAM files is calculated and displayed
# - The number of read groups and the number of BAM files is compared. The answer is "all good" when the number of BAM files is 2x the number of read groups from the text file.
# - Matching and non-matching samples are appended in different lists, which are displayed at the end.
#
# Read groups can be also directly retrieved from the BAM files, so these can be compared to the starting point / expected ones. Therefore, a total comparison of read groups would be: read groups from the text file *vs* number of read-group-specific FASTQ files *vs* number of read groups within the final BAM file.
#
# How to retrieve read groups from BAM files and compare to the read-group-specific FASTQ file:

# %%
# %%bash
# module load samtools/1.6
# path="/cluster/work/pausch/temp_scratch/audald/best_assembly"
# samples="RM1513 BSWCHEM111512030200"
# aligned="dedup_alignment"
# split_fastq="split_fastq"
# for sample in $samples
# do
#     cd $path
#     echo '---------- Sample' $sample '----------'
#     cd $split_fastq
#     echo 'Read groups once FASTQ are split:'
#     echo 'R1:'
#     ls $sample/${sample}*R1.fq.gz | wc -l
#     ls $sample/${sample}*R1.fq.gz | awk -F "_" '{print $2"."$3}'
#     echo 'R2:'
#     ls $sample/${sample}*R2.fq.gz | wc -l
#     ls $sample/${sample}*R2.fq.gz | awk -F "_" '{print $2"."$3}'
#     cd ../$aligned
#     echo 'Read groups for UCD alignment:'
#     samtools view -H UCD/$sample/$sample.bam | grep '@RG' | grep -v @PG | wc -l
#     samtools view -H UCD/$sample/$sample.bam | grep '@RG' | grep -v @PG | awk -F "\t" '{print $2}' | awk -F ":" '{print $2}'| sort -u #discarding the @PG header
#     echo 'Read groups for Angus alignment:'
#     samtools view -H UCD/$sample/$sample.bam | grep '@RG' | grep -v @PG | wc -l
#     samtools view -H UCD/$sample/$sample.bam | grep '@RG' | grep -v @PG | awk -F "\t" '{print $2}' | awk -F ":" '{print $2}'| sort -u #discarding the @PG header
# done
# Out:
# ---------- Sample RM1513 ----------
# Read groups once FASTQ are split:
# R1:
# 8
# H3WNWDSXX.1
# H3WNWDSXX.2
# H3WNWDSXX.3
# H3WNWDSXX.4
# H52LGDSXX.1
# H52LGDSXX.2
# H52LGDSXX.3
# H52LGDSXX.4
# R2:
# 8
# H3WNWDSXX.1
# H3WNWDSXX.2
# H3WNWDSXX.3
# H3WNWDSXX.4
# H52LGDSXX.1
# H52LGDSXX.2
# H52LGDSXX.3
# H52LGDSXX.4
# Read groups for UCD alignment:
# 8
# H3WNWDSXX.1
# H3WNWDSXX.2
# H3WNWDSXX.3
# H3WNWDSXX.4
# H52LGDSXX.1
# H52LGDSXX.2
# H52LGDSXX.3
# H52LGDSXX.4
# Read groups for Angus alignment:
# 8
# H3WNWDSXX.1
# H3WNWDSXX.2
# H3WNWDSXX.3
# H3WNWDSXX.4
# H52LGDSXX.1
# H52LGDSXX.2
# H52LGDSXX.3
# H52LGDSXX.4
# ---------- Sample BSWCHEM111512030200 ----------
# Read groups once FASTQ are split:
# R1:
# 1
# D1C72ACXX.4
# R2:
# 1
# D1C72ACXX.4
# Read groups for UCD alignment:
# 1
# D1C72ACXX.4
# Read groups for Angus alignment:
# 1
# D1C72ACXX.4

# %% [markdown]
# **Softwares and tools**
#
# - Picard tools can be used for validating the BAM files as indicated [here](http://broadinstitute.github.io/picard/command-line-overview.html#ValidateSamFile)

# %%
# %%bash
#
# cd /cluster/work/pausch/temp_scratch/audald/best_assembly/dedup_alignment
# module load picard/2.9.2
# echo 'Summary of BSWCHEM120070555216_H7HFFDSXX_1_UCD.bam via Picard tools'
# picard ValidateSamFile  I=UCD/BSWCHEM120070555216/BSWCHEM120070555216.bam MODE=SUMMARY
# echo 'Summary of BSWCHEM120070555216_H7HFFDSXX_1_Angus.bam via Picard tools'
# picard ValidateSamFile  I=Angus/BSWCHEM120070555216/BSWCHEM120070555216.bam MODE=SUMMARY
# Out:
# Summary of BSWCHEM120070555216_H7HFFDSXX_1_UCD.bam via Picard tools
# No errors found
# Summary of BSWCHEM120070555216_H7HFFDSXX_1_Angus.bam via Picard tools
# No errors found
# [Fri Feb 07 10:32:23 CET 2020] picard.sam.ValidateSamFile INPUT=UCD/BSWCHEM120070555216/BSWCHEM120070555216.bam MODE=SUMMARY    MAX_OUTPUT=100 IGNORE_WARNINGS=false VALIDATE_INDEX=true INDEX_VALIDATION_STRINGENCY=EXHAUSTIVE IS_BISULFITE_SEQUENCED=false MAX_OPEN_TEMP_FILES=8000 VERBOSITY=INFO QUIET=false VALIDATION_STRINGENCY=STRICT COMPRESSION_LEVEL=5 MAX_RECORDS_IN_RAM=500000 CREATE_INDEX=false CREATE_MD5_FILE=false GA4GH_CLIENT_SECRETS=client_secrets.json
# [Fri Feb 07 10:32:23 CET 2020] Executing as avillas@lo-a2-073 on Linux 3.10.0-862.14.4.el7.x86_64 amd64; Java HotSpot(TM) 64-Bit Server VM 1.8.0_141-b15; Picard version: 2.9.2-SNAPSHOT
# INFO	2020-02-07 10:33:04	SamFileValidator	Validated Read    10,000,000 records.  Elapsed time: 00:00:41s.  Time for last 10,000,000:   41s.  Last read position: 1:114,066,540
# INFO	2020-02-07 10:33:41	SamFileValidator	Validated Read    20,000,000 records.  Elapsed time: 00:01:17s.  Time for last 10,000,000:   36s.  Last read position: 2:70,528,039
# INFO	2020-02-07 10:34:17	SamFileValidator	Validated Read    30,000,000 records.  Elapsed time: 00:01:53s.  Time for last 10,000,000:   35s.  Last read position: 3:48,169,658
# INFO	2020-02-07 10:34:53	SamFileValidator	Validated Read    40,000,000 records.  Elapsed time: 00:02:29s.  Time for last 10,000,000:   36s.  Last read position: 4:42,438,752
# INFO	2020-02-07 10:35:30	SamFileValidator	Validated Read    50,000,000 records.  Elapsed time: 00:03:06s.  Time for last 10,000,000:   36s.  Last read position: 5:37,419,993
# INFO	2020-02-07 10:36:07	SamFileValidator	Validated Read    60,000,000 records.  Elapsed time: 00:03:43s.  Time for last 10,000,000:   36s.  Last read position: 6:31,832,207
# INFO	2020-02-07 10:36:44	SamFileValidator	Validated Read    70,000,000 records.  Elapsed time: 00:04:20s.  Time for last 10,000,000:   36s.  Last read position: 7:28,331,802
# INFO	2020-02-07 10:37:21	SamFileValidator	Validated Read    80,000,000 records.  Elapsed time: 00:04:57s.  Time for last 10,000,000:   37s.  Last read position: 8:32,674,079
# INFO	2020-02-07 10:37:58	SamFileValidator	Validated Read    90,000,000 records.  Elapsed time: 00:05:34s.  Time for last 10,000,000:   37s.  Last read position: 9:33,738,038
# INFO	2020-02-07 10:38:35	SamFileValidator	Validated Read   100,000,000 records.  Elapsed time: 00:06:11s.  Time for last 10,000,000:   37s.  Last read position: 10:45,111,415
# INFO	2020-02-07 10:39:13	SamFileValidator	Validated Read   110,000,000 records.  Elapsed time: 00:06:49s.  Time for last 10,000,000:   37s.  Last read position: 11:57,029,633
# INFO	2020-02-07 10:39:50	SamFileValidator	Validated Read   120,000,000 records.  Elapsed time: 00:07:26s.  Time for last 10,000,000:   37s.  Last read position: 12:65,446,410
# INFO	2020-02-07 10:40:27	SamFileValidator	Validated Read   130,000,000 records.  Elapsed time: 00:08:04s.  Time for last 10,000,000:   37s.  Last read position: 14:9,730,123
# INFO	2020-02-07 10:41:05	SamFileValidator	Validated Read   140,000,000 records.  Elapsed time: 00:08:41s.  Time for last 10,000,000:   37s.  Last read position: 15:42,167,184
# INFO	2020-02-07 10:41:42	SamFileValidator	Validated Read   150,000,000 records.  Elapsed time: 00:09:18s.  Time for last 10,000,000:   37s.  Last read position: 16:72,199,830
# INFO	2020-02-07 10:42:19	SamFileValidator	Validated Read   160,000,000 records.  Elapsed time: 00:09:56s.  Time for last 10,000,000:   37s.  Last read position: 18:33,363,125
# INFO	2020-02-07 10:42:57	SamFileValidator	Validated Read   170,000,000 records.  Elapsed time: 00:10:33s.  Time for last 10,000,000:   37s.  Last read position: 20:18,660,553
# INFO	2020-02-07 10:43:34	SamFileValidator	Validated Read   180,000,000 records.  Elapsed time: 00:11:11s.  Time for last 10,000,000:   37s.  Last read position: 21:59,770,702
# INFO	2020-02-07 10:44:12	SamFileValidator	Validated Read   190,000,000 records.  Elapsed time: 00:11:48s.  Time for last 10,000,000:   37s.  Last read position: 23:43,851,177
# INFO	2020-02-07 10:44:49	SamFileValidator	Validated Read   200,000,000 records.  Elapsed time: 00:12:26s.  Time for last 10,000,000:   37s.  Last read position: 26:1,848,679
# INFO	2020-02-07 10:45:27	SamFileValidator	Validated Read   210,000,000 records.  Elapsed time: 00:13:03s.  Time for last 10,000,000:   37s.  Last read position: 28:18,835,027
# INFO	2020-02-07 10:46:06	SamFileValidator	Validated Read   220,000,000 records.  Elapsed time: 00:13:42s.  Time for last 10,000,000:   38s.  Last read position: X:71,027,244
# INFO	2020-02-07 10:46:45	SamFileValidator	Validated Read   230,000,000 records.  Elapsed time: 00:14:21s.  Time for last 10,000,000:   39s.  Last read position: NKLS02000111.1:39,699
# INFO	2020-02-07 10:47:27	SamFileValidator	Validated Read   240,000,000 records.  Elapsed time: 00:15:04s.  Time for last 10,000,000:   42s.  Last read position: NKLS02000731.1:13,776
# INFO	2020-02-07 10:48:11	SamFileValidator	Validated Read   250,000,000 records.  Elapsed time: 00:15:47s.  Time for last 10,000,000:   43s.  Last read position: NKLS02001342.1:2,126
# INFO	2020-02-07 10:48:55	SamFileValidator	Validated Read   260,000,000 records.  Elapsed time: 00:16:31s.  Time for last 10,000,000:   44s.  Last read position: NKLS02001917.1:44,140
# [Fri Feb 07 10:59:45 CET 2020] picard.sam.ValidateSamFile done. Elapsed time: 27.37 minutes.
# Runtime.totalMemory()=1866989568
# [Fri Feb 07 10:59:46 CET 2020] picard.sam.ValidateSamFile INPUT=Angus/BSWCHEM120070555216/BSWCHEM120070555216.bam MODE=SUMMARY    MAX_OUTPUT=100 IGNORE_WARNINGS=false VALIDATE_INDEX=true INDEX_VALIDATION_STRINGENCY=EXHAUSTIVE IS_BISULFITE_SEQUENCED=false MAX_OPEN_TEMP_FILES=8000 VERBOSITY=INFO QUIET=false VALIDATION_STRINGENCY=STRICT COMPRESSION_LEVEL=5 MAX_RECORDS_IN_RAM=500000 CREATE_INDEX=false CREATE_MD5_FILE=false GA4GH_CLIENT_SECRETS=client_secrets.json
# [Fri Feb 07 10:59:46 CET 2020] Executing as avillas@lo-a2-073 on Linux 3.10.0-862.14.4.el7.x86_64 amd64; Java HotSpot(TM) 64-Bit Server VM 1.8.0_141-b15; Picard version: 2.9.2-SNAPSHOT
# INFO	2020-02-07 11:00:26	SamFileValidator	Validated Read    10,000,000 records.  Elapsed time: 00:00:39s.  Time for last 10,000,000:   39s.  Last read position: 1:114,784,801
# INFO	2020-02-07 11:01:02	SamFileValidator	Validated Read    20,000,000 records.  Elapsed time: 00:01:15s.  Time for last 10,000,000:   36s.  Last read position: 2:72,405,909
# INFO	2020-02-07 11:01:38	SamFileValidator	Validated Read    30,000,000 records.  Elapsed time: 00:01:52s.  Time for last 10,000,000:   36s.  Last read position: 3:52,811,274
# INFO	2020-02-07 11:02:15	SamFileValidator	Validated Read    40,000,000 records.  Elapsed time: 00:02:28s.  Time for last 10,000,000:   36s.  Last read position: 4:46,663,292
# INFO	2020-02-07 11:02:53	SamFileValidator	Validated Read    50,000,000 records.  Elapsed time: 00:03:06s.  Time for last 10,000,000:   37s.  Last read position: 5:42,016,760
# INFO	2020-02-07 11:03:31	SamFileValidator	Validated Read    60,000,000 records.  Elapsed time: 00:03:44s.  Time for last 10,000,000:   38s.  Last read position: 6:35,165,805
# INFO	2020-02-07 11:04:09	SamFileValidator	Validated Read    70,000,000 records.  Elapsed time: 00:04:22s.  Time for last 10,000,000:   38s.  Last read position: 7:33,055,331
# INFO	2020-02-07 11:04:48	SamFileValidator	Validated Read    80,000,000 records.  Elapsed time: 00:05:01s.  Time for last 10,000,000:   38s.  Last read position: 8:37,886,360
# INFO	2020-02-07 11:05:26	SamFileValidator	Validated Read    90,000,000 records.  Elapsed time: 00:05:39s.  Time for last 10,000,000:   38s.  Last read position: 9:40,057,829
# INFO	2020-02-07 11:06:05	SamFileValidator	Validated Read   100,000,000 records.  Elapsed time: 00:06:18s.  Time for last 10,000,000:   38s.  Last read position: 10:46,793,274
# INFO	2020-02-07 11:06:43	SamFileValidator	Validated Read   110,000,000 records.  Elapsed time: 00:06:56s.  Time for last 10,000,000:   38s.  Last read position: 11:59,221,085
# INFO	2020-02-07 11:07:22	SamFileValidator	Validated Read   120,000,000 records.  Elapsed time: 00:07:35s.  Time for last 10,000,000:   38s.  Last read position: 12:68,150,526
# INFO	2020-02-07 11:08:01	SamFileValidator	Validated Read   130,000,000 records.  Elapsed time: 00:08:15s.  Time for last 10,000,000:   39s.  Last read position: 14:8,556,440
# INFO	2020-02-07 11:08:40	SamFileValidator	Validated Read   140,000,000 records.  Elapsed time: 00:08:53s.  Time for last 10,000,000:   38s.  Last read position: 15:38,427,055
# INFO	2020-02-07 11:09:18	SamFileValidator	Validated Read   150,000,000 records.  Elapsed time: 00:09:32s.  Time for last 10,000,000:   38s.  Last read position: 16:69,839,628
# INFO	2020-02-07 11:09:57	SamFileValidator	Validated Read   160,000,000 records.  Elapsed time: 00:10:11s.  Time for last 10,000,000:   38s.  Last read position: 18:32,396,341
# INFO	2020-02-07 11:10:36	SamFileValidator	Validated Read   170,000,000 records.  Elapsed time: 00:10:49s.  Time for last 10,000,000:   38s.  Last read position: 20:21,068,257
# INFO	2020-02-07 11:11:14	SamFileValidator	Validated Read   180,000,000 records.  Elapsed time: 00:11:28s.  Time for last 10,000,000:   38s.  Last read position: 21:63,717,309
# INFO	2020-02-07 11:11:53	SamFileValidator	Validated Read   190,000,000 records.  Elapsed time: 00:12:07s.  Time for last 10,000,000:   38s.  Last read position: 23:48,680,170
# INFO	2020-02-07 11:12:33	SamFileValidator	Validated Read   200,000,000 records.  Elapsed time: 00:12:46s.  Time for last 10,000,000:   39s.  Last read position: 26:10,191,240
# INFO	2020-02-07 11:13:11	SamFileValidator	Validated Read   210,000,000 records.  Elapsed time: 00:13:25s.  Time for last 10,000,000:   38s.  Last read position: 28:30,460,359
# INFO	2020-02-07 11:13:51	SamFileValidator	Validated Read   220,000,000 records.  Elapsed time: 00:14:05s.  Time for last 10,000,000:   40s.  Last read position: PUFT02000041.1:929,497
# INFO	2020-02-07 11:14:33	SamFileValidator	Validated Read   230,000,000 records.  Elapsed time: 00:14:46s.  Time for last 10,000,000:   41s.  Last read position: PUFT02000412.1:47,992
# INFO	2020-02-07 11:15:15	SamFileValidator	Validated Read   240,000,000 records.  Elapsed time: 00:15:29s.  Time for last 10,000,000:   42s.  Last read position: PUFT02000516.1:33,364
# INFO	2020-02-07 11:15:59	SamFileValidator	Validated Read   250,000,000 records.  Elapsed time: 00:16:13s.  Time for last 10,000,000:   44s.  Last read position: PUFT02000843.1:9,362
# INFO	2020-02-07 11:16:49	SamFileValidator	Validated Read   260,000,000 records.  Elapsed time: 00:17:02s.  Time for last 10,000,000:   49s.  Last read position: PUFT02001409.1:46,895
# [Fri Feb 07 11:28:30 CET 2020] picard.sam.ValidateSamFile done. Elapsed time: 28.74 minutes.
# Runtime.totalMemory()=1823473664

# %% [markdown]
# - Samtools may be another option for validation.
